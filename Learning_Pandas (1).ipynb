# %%
# !wget /content/drive/MyDrive/JPMCHackathonStuff/winemag-data-130k-v2.csv
# Out:
# /content/drive/MyDrive/JPMCHackathonStuff/winemag-data-130k-v2.csv: Scheme missing.

# %%
import pandas as pd
import math
import cmath



#pd.DataFrame({"Yes":[51, 21], "No":[131,2]})

#pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']}, index=["Product A", "Product B"])

#pd.Series([1,2,3,4,5], index=['2015 Sales', '2016 Sales', '2017 Sales',"2018 Sales","2019 Sales"])



MasterList = pd.read_csv("/content/drive/MyDrive/JPMCHackathonStuff/2023-2024 Master School List (20231003).csv")




#SchoolList.groupby(["Zip Code"])

#["Zip Code"]
# print(newlist)

SchoolList = MasterList[["Zip Code","Publication Name", "ULCS Code"]]
SchoolList
#SchoolList.merge(df2, on = 'Zip',how =)
# Out:
#      Zip Code                             Publication Name  ULCS Code
# 0       19142                     John Bartram High School       1010
# 1       19139                West Philadelphia High School       1020
# 2       19104                    High School of the Future       1030
# 3       19104  Paul Robeson High School for Human Services       1050
# 4       19139                 William L. Sayre High School       1100
# ..        ...                                          ...        ...
# 324     19121                       One Bright Ray Mansion       8860
# 325     19121               One Bright Ray Mansion Evening       8870
# 326     19124              One Bright Ray - Simpson Campus       8890
# 327     19124             One Bright Ray Simpson - Evening       8891
# 328     19130                         Re-Engagement Center       8900
#
# [329 rows x 3 columns]

# %%
type(SchoolList)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("/content/drive/MyDrive/JPMCHackathonStuff/2023-2024 Master School List (20231003).csv")
# Out:
#      PA Code NSC Code     NCES Code     AUN Code  ULCS Code SRC School ID  \
# 0     3847.0   393345  4.218990e+11  126515001.0       1010           101
# 1     3860.0   393555  4.218990e+11  126515001.0       1020           102
# 2     7903.0   392779  4.218990e+11  126515001.0       1030           103
# 3     7780.0   393347  4.218990e+11  126515001.0       1050           105
# 4     7245.0   393944  4.218990e+11  126515001.0       1100           110
# ..       ...      ...           ...          ...        ...           ...
# 324      NaN   390081           NaN  126515001.0       8860           886
# 325      NaN   A26193           NaN  126515001.0       8870           887
# 326      NaN   390035           NaN  126515001.0       8890           889
# 327      NaN      NaN           NaN  126515001.0       8891           NaN
# 328      NaN      NaN           NaN  126515001.0       8900           890
#
#                    School Name (ULCS)  \
# 0            JOHN BARTRAM HIGH SCHOOL
# ...

# %%
SchoolList.head()
# Out:
#    Zip Code                             Publication Name  ULCS Code
# 0     19142                     John Bartram High School       1010
# 1     19139                West Philadelphia High School       1020
# 2     19104                    High School of the Future       1030
# 3     19104  Paul Robeson High School for Human Services       1050
# 4     19139                 William L. Sayre High School       1100

# %%
'''
UsZip = pd.read_csv("/content/drive/MyDrive/JPMCHackathonStuff/uszips.csv")
LocZip=UsZip
LocZip[(LocZip["zip"]>=19102)&(LocZip["zip"]<=19154)]
SchoolList = MasterList[["Zip Code","Publication Name", "ULCS Code"]]
'''

GovSucks = pd.read_csv("/content/drive/MyDrive/JPMCHackathonStuff/TheGovernmentSucks - Sheet1.csv")
IncomeZip = GovSucks
#IncomeZip
schoolIncomes = SchoolList.merge(IncomeZip, on = 'Zip Code',how ="left")
schoolIncomes.sort_values(by = "Income", ascending = True, inplace = True)
schoolIncomes



# SchoolList
# Out:
#      Zip Code                                  Publication Name  ULCS Code  \
# 173     19132                          Richard R. Wright School       4470
# 147     19132                        TECH Freire Charter School       3441
# 159     19132  Murrell Dobbins Career and Technical High School       4060
# 167     19132                       E. Washington Rhodes School       4350
# 170     19132                           Thomas M. Peirce School       4380
# ..        ...                                               ...        ...
# 55      19147                         George W. Nebinger School       2590
# 73      19147               Christopher Columbus Charter School       3306
# 41      19106                   General George A. McCall School       2340
# 102     19106                 Mastery Charter School at Lenfest       3361
# 60      19106                          Constitution High School       2670
#
#      Income
# 173   26041
# 147   26041
# 159   26041
# 167   26041
# ...

# %%
SchoolList["Zip Code"].unique()
# Out:
# array([19142, 19139, 19104, 19143, 19153, 19131, 19148, 19130, 19147,
#        19145, 19146, 19121, 19106, 19103, 19140, 19123, 19125, 19124,
#        19120, 19151, 19122, 19138, 19116, 19137, 19136, 19144, 19128,
#        19132, 19135, 19133, 19111, 19141, 19134, 19154, 19129, 19150,
#        19119, 19118, 19127, 19126, 19149, 19114, 19115, 19152])

# %%
from pathlib import Path


gradRates = pd.read_csv("/content/drive/MyDrive/JPMCHackathonStuff/JPMCSchoolStuff - Copy of SDP_Graduation_Rates_School_S_2023-02-15.csv")
enrollDemo = pd.read_csv("/content/drive/MyDrive/JPMCHackathonStuff/JPMCSchoolStuff - Copy of 2023-2024 Enrollment & Demographics.csv")
collegeMatr = pd.read_csv("/content/drive/MyDrive/JPMCHackathonStuff/JPMCSchoolStuff - Copy of SDP_College_Matriculation_2021-2022.csv")

gradRates = gradRates[(gradRates["cohort"]=="2018-2019")&(gradRates["SubGroup"]=="All Students")]

enrollDemo = enrollDemo[(enrollDemo["GradeLevel"]=="All Grades")]



gradEnroll = gradRates.merge(enrollDemo, on = 'ULCS Code',how ="left")

gradEnroll_CollegeMatr = gradEnroll.merge(collegeMatr, on = 'ULCS Code',how ="left")

gradEnroll_CollegeMatr.sort_values(by = "ULCS Code", ascending = True, inplace = True)

schoolData = schoolIncomes.merge(gradEnroll_CollegeMatr, on = 'ULCS Code',how ="left")
schoolData.sort_values(by = "Income", ascending = True, inplace = True)

schoolData = schoolData[['Zip Code', 'Publication Name', 'ULCS Code', 'Income',
       'Denom', 'Num', 'Graduation Percent', 'StudentEnrollment', 'IEPCount', 'IEPPCT',
       'NotIEPCount', 'NotIEPPCT', 'FemaleCount', 'FemalePCT', 'MaleCount', 'MalePCT', 'BlackAACount',
      'BlackAAPCT', 'WhiteCount', 'WhitePCT', 'EconDisadvRate', 'OtherRaceCount',
      'OtherRacePCT', 'Number of Graduates', 'First-Fall Matriculation Rate']]


#gradRates.keys()

#schoolData.keys()





schoolData
# Zip Code', 'Publication Name', 'ULCS Code', 'Income',
#        'Denom', 'Num', 'Graduation Percent', 'StudentEnrollment', 'IEPCount', 'IEPPCT',
#        'NotIEPCount', 'NotIEPPCT', 'FemaleCount', 'FemalePCT', 'MaleCount', 'MalePCT', 'BlackAACount',
#        'BlackAAPCT', 'WhiteCount', 'WhitePCT', 'EconDisadvRate', 'OtherRaceCount',
#        'OtherRacePCT', 'Number of Graduates', 'First-Fall Matriculation Rate'])

#gradRates.to_csv('/content/drive/MyDrive/JPMCHackathonStuff/gradRatesOut.csv')
schoolData.to_csv('/content/drive/MyDrive/JPMCHackathonStuff/schoolOut.csv')

# %%
# radius15 = pd.read_csv("/content/drive/MyDrive/JPMCHackathonStuff/15milesraduis.csv")



# mile15Schools = schoolData.merge(radius15, on = 'Zip Code',how ="left")

# mile15Schools
# gradRates = gradRates[(gradRates["cohort"]=="2018-2019")&(gradRates["SubGroup"]=="All Students")]

# gradRates.to_csv('/content/drive/MyDrive/JPMCHackathonStuff/gradRatesOut.csv')
# schoolData.to_csv('/content/drive/MyDrive/JPMCHackathonStuff/schoolOut.csv')
